# %%
import tensorflow as tf
# Out:
# /home/wujiaocan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 1.参数设置

# %%
# 参数设置
SRC_TRAIN_DATA = './data/train.en'
TRG_TRAIN_DATA = './data/train.zh'
CHECKPOINT_PATH = './data/seq2seq_ckpt'

HIDDEN_SIZE = 1024
NUM_LAYERS = 2
SRC_VOCAB_SIZE = 10000
TRG_VOCAB_SIZE = 4000
BATCH_SIZE = 100
NUM_EPOCH = 20
KEEP_PROB = 0.8
MAX_GRAD_NORM = 5
SHARE_EMB_AND_SOFTMAX = True

MAX_LEN = 50
SOS_ID = 1

# %% [markdown]
# ### 2.读取训练数据并创建Dataset

# %%
# 使用Dataset从一个文件中读取一个语言的数据。
# 数据的格式为每行一句话，单词已经转化为单词编号。
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # 根据空格将单词编号切分开并放入一个一维向量。
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # 将字符串形式的单词编号转化为整数。
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # 统计每个句子的单词数量，并与句子内容一起放入Dataset中。
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

# 从源语言文件src_path和目标语言文件trg_path中分别读取数据，并进行填充和
# batching操作。
def MakeSrcTrgDataset(src_path, trg_path, batch_size):
    # 首先分别读取源语言数据和目标语言数据。
    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    # 通过zip操作将两个Dataset合并为一个Dataset。现在每个Dataset中每一项数据ds
    # 由4个张量组成：
    #   ds[0][0]是源句子
    #   ds[0][1]是源句子长度
    #   ds[1][0]是目标句子
    #   ds[1][1]是目标句子长度
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # 删除内容为空（只包含<EOS>）的句子和长度过长的句子。
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    # 从图9-5可知，解码器需要两种格式的目标句子：
    #   1.解码器的输入(trg_input)，形式如同"<sos> X Y Z"
    #   2.解码器的目标输出(trg_label)，形式如同"X Y Z <eos>"
    # 上面从文件中读到的目标句子是"X Y Z <eos>"的形式，我们需要从中生成"<sos> X Y Z"
    # 形式并加入到Dataset中。
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    dataset = dataset.map(MakeTrgInput)

    # 随机打乱训练数据。
    dataset = dataset.shuffle(10000)

    # 规定填充后输出的数据维度。
    padded_shapes = (
        (tf.TensorShape([None]),      # 源句子是长度未知的向量
         tf.TensorShape([])),         # 源句子长度是单个数字
        (tf.TensorShape([None]),      # 目标句子（解码器输入）是长度未知的向量
         tf.TensorShape([None]),      # 目标句子（解码器目标输出）是长度未知的向量
         tf.TensorShape([])))         # 目标句子长度是单个数字
    # 调用padded_batch方法进行batching操作。
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ### 3. 定义翻译模型

# %%
# 定义NMTModel类来描述模型。
class NMTModel(object):
    # 在模型的初始化函数中定义模型要用到的变量。
    def __init__(self):
        # 定义编码器和解码器所使用的LSTM结构。
        self.enc_cell = tf.nn.rnn_cell.MultiRNNCell(
          [tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
           for _ in range(NUM_LAYERS)])
        self.dec_cell = tf.nn.rnn_cell.MultiRNNCell(
          [tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE) 
           for _ in range(NUM_LAYERS)])

        # 为源语言和目标语言分别定义词向量。   
        self.src_embedding = tf.get_variable(
            "src_emb", [SRC_VOCAB_SIZE, HIDDEN_SIZE])
        self.trg_embedding = tf.get_variable(
            "trg_emb", [TRG_VOCAB_SIZE, HIDDEN_SIZE])

        # 定义softmax层的变量
        if SHARE_EMB_AND_SOFTMAX:
           self.softmax_weight = tf.transpose(self.trg_embedding)
        else:
           self.softmax_weight = tf.get_variable(
               "weight", [HIDDEN_SIZE, TRG_VOCAB_SIZE])
        self.softmax_bias = tf.get_variable(
            "softmax_bias", [TRG_VOCAB_SIZE])

    # 在forward函数中定义模型的前向计算图。
    # src_input, src_size, trg_input, trg_label, trg_size分别是上面
    # MakeSrcTrgDataset函数产生的五种张量。
    def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
        batch_size = tf.shape(src_input)[0]
    
        # 将输入和输出单词编号转为词向量。
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)
        
        # 在词向量上进行dropout。
        src_emb = tf.nn.dropout(src_emb, KEEP_PROB)
        trg_emb = tf.nn.dropout(trg_emb, KEEP_PROB)

        # 使用dynamic_rnn构造编码器。
        # 编码器读取源句子每个位置的词向量，输出最后一步的隐藏状态enc_state。
        # 因为编码器是一个双层LSTM，因此enc_state是一个包含两个LSTMStateTuple类
        # 张量的tuple，每个LSTMStateTuple对应编码器中的一层。
        # enc_outputs是顶层LSTM在每一步的输出，它的维度是[batch_size, 
        # max_time, HIDDEN_SIZE]。Seq2Seq模型中不需要用到enc_outputs，而
        # 后面介绍的attention模型会用到它。
        with tf.variable_scope("encoder"):
            enc_outputs, enc_state = tf.nn.dynamic_rnn(
                self.enc_cell, src_emb, src_size, dtype=tf.float32)

        # 使用dyanmic_rnn构造解码器。
        # 解码器读取目标句子每个位置的词向量，输出的dec_outputs为每一步
        # 顶层LSTM的输出。dec_outputs的维度是 [batch_size, max_time,
        # HIDDEN_SIZE]。
        # initial_state=enc_state表示用编码器的输出来初始化第一步的隐藏状态。
        with tf.variable_scope("decoder"):
            dec_outputs, _ = tf.nn.dynamic_rnn(
                self.dec_cell, trg_emb, trg_size, initial_state=enc_state)

        # 计算解码器每一步的log perplexity。这一步与语言模型代码相同。
        output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
        logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
        loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=tf.reshape(trg_label, [-1]), logits=logits)

        # 在计算平均损失时，需要将填充位置的权重设置为0，以避免无效位置的预测干扰
        # 模型的训练。
        label_weights = tf.sequence_mask(
            trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
        label_weights = tf.reshape(label_weights, [-1])
        cost = tf.reduce_sum(loss * label_weights)
        cost_per_token = cost / tf.reduce_sum(label_weights)
        
        # 定义反向传播操作。反向操作的实现与语言模型代码相同。
        trainable_variables = tf.trainable_variables()

        # 控制梯度大小，定义优化方法和训练步骤。
        grads = tf.gradients(cost / tf.to_float(batch_size),
                             trainable_variables)
        grads, _ = tf.clip_by_global_norm(grads, MAX_GRAD_NORM)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0)
        train_op = optimizer.apply_gradients(
            zip(grads, trainable_variables))
        return cost_per_token, train_op

# %% [markdown]
# ### 4. 训练过程和主函数

# %%
# 使用给定的模型model上训练一个epoch，并返回全局步数。
# 每训练200步便保存一个checkpoint。
def run_epoch(session, cost_op, train_op, saver, step):
    # 训练一个epoch。
    # 重复训练步骤直至遍历完Dataset中所有数据。
    while True:
        try:
            # 运行train_op并计算损失值。训练数据在main()函数中以Dataset方式提供。
            cost, _ = session.run([cost_op, train_op])
            if step % 10 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # 每200步保存一个checkpoint。
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

def main():
    tf.reset_default_graph()
    # 定义初始化函数。
    initializer = tf.random_uniform_initializer(-0.05, 0.05)

    # 定义训练用的循环神经网络模型。
    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel()
  
    # 定义输入数据。
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # 定义前向计算图。输入数据以张量形式提供给forward函数。
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # 训练模型。
    saver = tf.train.Saver()
    step = 0
    with tf.Session() as sess:
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            print("In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            
if __name__ == "__main__":
    main()
# Out:
# In iteration: 1
# After 0 steps, per token cost is 8.293
# After 10 steps, per token cost is 8.007
# After 20 steps, per token cost is 9.576
# After 30 steps, per token cost is 7.203
# After 40 steps, per token cost is 6.832
# After 50 steps, per token cost is 6.671
# After 60 steps, per token cost is 6.574
# After 70 steps, per token cost is 6.521
# After 80 steps, per token cost is 6.653
# After 90 steps, per token cost is 6.511
# After 100 steps, per token cost is 6.369
# After 110 steps, per token cost is 6.364
# After 120 steps, per token cost is 6.215
# After 130 steps, per token cost is 6.208
# After 140 steps, per token cost is 6.086
# After 150 steps, per token cost is 6.189
# After 160 steps, per token cost is 5.917
# After 170 steps, per token cost is 6.015
# After 180 steps, per token cost is 6.092
# After 190 steps, per token cost is 5.949
# After 200 steps, per token cost is 5.960
# After 210 steps, per token cost is 5.797
# After 220 steps, per token cost is 5.753
# After 230 steps, per token cost is 5.876
# After 240 steps, per token cost is 5.908
# After 250 steps, per token cost is 5.668
# After 260 steps, per token cost is 5.687
# After 270 steps, per token cost is 5.570
# After 280 steps, per token cost is 5.611
# After 290 steps, per token cost is 5.661
# After 300 steps, per token cost is 5.501
# After 310 steps, per token cost is 5.578
# After 320 steps, per token cost is 5.436
# After 330 steps, per token cost is 5.604
# After 340 steps, per token cost is 5.320
# After 350 steps, per token cost is 5.359
# After 360 steps, per token cost is 5.237
# After 370 steps, per token cost is 5.254
# After 380 steps, per token cost is 5.213
# After 390 steps, per token cost is 5.166
# After 400 steps, per token cost is 5.006
# After 410 steps, per token cost is 5.159
# After 420 steps, per token cost is 5.226
# After 430 steps, per token cost is 5.032
# After 440 steps, per token cost is 4.836
# After 450 steps, per token cost is 4.929
# After 460 steps, per token cost is 4.983
# After 470 steps, per token cost is 4.873
# After 480 steps, per token cost is 4.906
# After 490 steps, per token cost is 4.843
# After 500 steps, per token cost is 4.914
# After 510 steps, per token cost is 4.781
# After 520 steps, per token cost is 4.983
# After 530 steps, per token cost is 4.859
# After 540 steps, per token cost is 4.696
# After 550 steps, per token cost is 4.738
# After 560 steps, per token cost is 4.751
# In iteration: 2
# After 570 steps, per token cost is 4.690
# After 580 steps, per token cost is 4.576
# After 590 steps, per token cost is 4.666
# After 600 steps, per token cost is 4.620
# After 610 steps, per token cost is 4.541
# After 620 steps, per token cost is 4.659
# After 630 steps, per token cost is 4.579
# After 640 steps, per token cost is 4.466
# After 650 steps, per token cost is 4.589
# After 660 steps, per token cost is 4.567
# After 670 steps, per token cost is 4.468
# After 680 steps, per token cost is 4.382
# After 690 steps, per token cost is 4.435
# After 700 steps, per token cost is 4.350
# After 710 steps, per token cost is 4.331
# After 720 steps, per token cost is 4.498
# After 730 steps, per token cost is 4.286
# After 740 steps, per token cost is 4.167
# After 750 steps, per token cost is 4.359
# After 760 steps, per token cost is 4.395
# After 770 steps, per token cost is 4.283
# After 780 steps, per token cost is 4.401
# After 790 steps, per token cost is 4.273
# After 800 steps, per token cost is 4.142
# After 810 steps, per token cost is 4.288
# After 820 steps, per token cost is 4.174
# After 830 steps, per token cost is 4.077
# After 840 steps, per token cost is 4.234
# After 850 steps, per token cost is 4.208
# After 860 steps, per token cost is 4.153
# After 870 steps, per token cost is 4.193
# After 880 steps, per token cost is 4.197
# After 890 steps, per token cost is 3.969
# After 900 steps, per token cost is 4.080
# After 910 steps, per token cost is 4.086
# After 920 steps, per token cost is 4.246
# After 930 steps, per token cost is 4.079
# After 940 steps, per token cost is 3.994
# After 950 steps, per token cost is 4.009
# After 960 steps, per token cost is 4.027
# After 970 steps, per token cost is 4.014
# After 980 steps, per token cost is 4.047
# After 990 steps, per token cost is 4.133
# After 1000 steps, per token cost is 3.893
# After 1010 steps, per token cost is 3.994
# After 1020 steps, per token cost is 3.949
# After 1030 steps, per token cost is 4.018
# After 1040 steps, per token cost is 4.084
# After 1050 steps, per token cost is 4.072
# After 1060 steps, per token cost is 4.042
# After 1070 steps, per token cost is 4.181
# After 1080 steps, per token cost is 3.922
# After 1090 steps, per token cost is 4.089
# After 1100 steps, per token cost is 3.845
# After 1110 steps, per token cost is 3.928
# After 1120 steps, per token cost is 3.945
# In iteration: 3
# After 1130 steps, per token cost is 4.045
# After 1140 steps, per token cost is 3.998
# After 1150 steps, per token cost is 3.813
# After 1160 steps, per token cost is 3.939
# After 1170 steps, per token cost is 4.130
# After 1180 steps, per token cost is 3.898
# After 1190 steps, per token cost is 3.813
# After 1200 steps, per token cost is 3.921
# After 1210 steps, per token cost is 3.926
# After 1220 steps, per token cost is 4.076
# After 1230 steps, per token cost is 3.885
# After 1240 steps, per token cost is 3.946
# After 1250 steps, per token cost is 3.966
# After 1260 steps, per token cost is 3.823
# After 1270 steps, per token cost is 3.845
# After 1280 steps, per token cost is 3.778
# After 1290 steps, per token cost is 3.742
# After 1300 steps, per token cost is 3.860
# After 1310 steps, per token cost is 3.745
# After 1320 steps, per token cost is 3.864
# After 1330 steps, per token cost is 3.717
# After 1340 steps, per token cost is 3.901
# After 1350 steps, per token cost is 3.806
# After 1360 steps, per token cost is 3.723
# After 1370 steps, per token cost is 3.592
# After 1380 steps, per token cost is 3.709
# After 1390 steps, per token cost is 3.817
# After 1400 steps, per token cost is 3.714
# After 1410 steps, per token cost is 3.664
# After 1420 steps, per token cost is 3.664
# After 1430 steps, per token cost is 3.724
# After 1440 steps, per token cost is 3.715
# After 1450 steps, per token cost is 3.686
# After 1460 steps, per token cost is 3.713
# After 1470 steps, per token cost is 3.535
# After 1480 steps, per token cost is 3.765
# After 1490 steps, per token cost is 3.692
# After 1500 steps, per token cost is 3.563
# After 1510 steps, per token cost is 3.643
# After 1520 steps, per token cost is 3.802
# After 1530 steps, per token cost is 3.626
# After 1540 steps, per token cost is 3.573
# After 1550 steps, per token cost is 3.589
# After 1560 steps, per token cost is 3.618
# After 1570 steps, per token cost is 3.639
# After 1580 steps, per token cost is 3.588
# After 1590 steps, per token cost is 3.742
# After 1600 steps, per token cost is 3.677
# After 1610 steps, per token cost is 3.561
# After 1620 steps, per token cost is 3.588
# After 1630 steps, per token cost is 3.646
# After 1640 steps, per token cost is 3.677
# After 1650 steps, per token cost is 3.555
# After 1660 steps, per token cost is 3.491
# After 1670 steps, per token cost is 3.636
# After 1680 steps, per token cost is 3.698
# After 1690 steps, per token cost is 3.508
# In iteration: 4
# After 1700 steps, per token cost is 3.690
# After 1710 steps, per token cost is 3.667
# After 1720 steps, per token cost is 3.624
# After 1730 steps, per token cost is 3.404
# After 1740 steps, per token cost is 3.662
# After 1750 steps, per token cost is 3.480
# After 1760 steps, per token cost is 3.598
# After 1770 steps, per token cost is 3.619
# After 1780 steps, per token cost is 3.527
# After 1790 steps, per token cost is 3.519
# After 1800 steps, per token cost is 3.551
# After 1810 steps, per token cost is 3.609
# After 1820 steps, per token cost is 3.422
# After 1830 steps, per token cost is 3.465
# After 1840 steps, per token cost is 3.618
# After 1850 steps, per token cost is 3.582
# After 1860 steps, per token cost is 3.499
# After 1870 steps, per token cost is 3.423
# After 1880 steps, per token cost is 3.449
# After 1890 steps, per token cost is 3.446
# After 1900 steps, per token cost is 3.544
# After 1910 steps, per token cost is 3.550
# After 1920 steps, per token cost is 3.442
# After 1930 steps, per token cost is 3.397
# After 1940 steps, per token cost is 3.416
# After 1950 steps, per token cost is 3.421
# After 1960 steps, per token cost is 3.473
# After 1970 steps, per token cost is 3.545
# After 1980 steps, per token cost is 3.384
# After 1990 steps, per token cost is 3.377
# After 2000 steps, per token cost is 3.397
# After 2010 steps, per token cost is 3.451
# After 2020 steps, per token cost is 3.414
# After 2030 steps, per token cost is 3.349
# After 2040 steps, per token cost is 3.461
# After 2050 steps, per token cost is 3.475
# After 2060 steps, per token cost is 3.292
# After 2070 steps, per token cost is 3.557
# After 2080 steps, per token cost is 3.399
# After 2090 steps, per token cost is 3.207
# After 2100 steps, per token cost is 3.318
# After 2110 steps, per token cost is 3.440
# After 2120 steps, per token cost is 3.307
# After 2130 steps, per token cost is 3.534
# After 2140 steps, per token cost is 3.467
# After 2150 steps, per token cost is 3.429
# After 2160 steps, per token cost is 3.379
# After 2170 steps, per token cost is 3.383
# After 2180 steps, per token cost is 3.406
# After 2190 steps, per token cost is 3.397
# After 2200 steps, per token cost is 3.385
# After 2210 steps, per token cost is 3.345
# After 2220 steps, per token cost is 3.371
# After 2230 steps, per token cost is 3.303
# After 2240 steps, per token cost is 3.255
# After 2250 steps, per token cost is 3.299
# In iteration: 5
# After 2260 steps, per token cost is 3.570
# After 2270 steps, per token cost is 3.355
# After 2280 steps, per token cost is 3.359
# After 2290 steps, per token cost is 3.290
# After 2300 steps, per token cost is 3.369
# After 2310 steps, per token cost is 3.317
# After 2320 steps, per token cost is 3.299
# After 2330 steps, per token cost is 3.332
# After 2340 steps, per token cost is 3.224
# After 2350 steps, per token cost is 3.272
# After 2360 steps, per token cost is 3.358
# After 2370 steps, per token cost is 3.204
# After 2380 steps, per token cost is 3.251
# After 2390 steps, per token cost is 3.199
# After 2400 steps, per token cost is 3.197
# After 2410 steps, per token cost is 3.216
# After 2420 steps, per token cost is 3.295
# After 2430 steps, per token cost is 3.169
# After 2440 steps, per token cost is 3.101
# After 2450 steps, per token cost is 3.233
# After 2460 steps, per token cost is 3.175
# After 2470 steps, per token cost is 3.220
# After 2480 steps, per token cost is 3.281
# After 2490 steps, per token cost is 3.207
# After 2500 steps, per token cost is 3.109
# After 2510 steps, per token cost is 3.080
# After 2520 steps, per token cost is 3.307
# After 2530 steps, per token cost is 3.159
# After 2540 steps, per token cost is 3.088
# After 2550 steps, per token cost is 3.179
# After 2560 steps, per token cost is 3.098
# After 2570 steps, per token cost is 3.131
# After 2580 steps, per token cost is 3.113
# After 2590 steps, per token cost is 3.244
# After 2600 steps, per token cost is 3.130
# After 2610 steps, per token cost is 3.004
# After 2620 steps, per token cost is 3.160
# After 2630 steps, per token cost is 3.105
# After 2640 steps, per token cost is 3.107
# After 2650 steps, per token cost is 3.067
# After 2660 steps, per token cost is 3.323
# After 2670 steps, per token cost is 3.071
# After 2680 steps, per token cost is 3.150
# After 2690 steps, per token cost is 3.055
# After 2700 steps, per token cost is 3.032
# After 2710 steps, per token cost is 2.996
# After 2720 steps, per token cost is 3.122
# After 2730 steps, per token cost is 3.067
# After 2740 steps, per token cost is 3.275
# After 2750 steps, per token cost is 3.047
# After 2760 steps, per token cost is 3.082
# After 2770 steps, per token cost is 3.051
# After 2780 steps, per token cost is 3.169
# After 2790 steps, per token cost is 3.188
# After 2800 steps, per token cost is 3.113
# After 2810 steps, per token cost is 3.031
# After 2820 steps, per token cost is 3.206
# In iteration: 6
# After 2830 steps, per token cost is 3.209
# After 2840 steps, per token cost is 2.984
# After 2850 steps, per token cost is 3.077
# After 2860 steps, per token cost is 3.064
# After 2870 steps, per token cost is 2.994
# After 2880 steps, per token cost is 2.888
# After 2890 steps, per token cost is 3.021
# After 2900 steps, per token cost is 3.052
# After 2910 steps, per token cost is 2.949
# After 2920 steps, per token cost is 3.120
# After 2930 steps, per token cost is 3.008
# After 2940 steps, per token cost is 3.065
# After 2950 steps, per token cost is 3.007
# After 2960 steps, per token cost is 2.930
# After 2970 steps, per token cost is 2.942
# After 2980 steps, per token cost is 3.007
# After 2990 steps, per token cost is 2.836
# After 3000 steps, per token cost is 2.996
# After 3010 steps, per token cost is 2.921
# After 3020 steps, per token cost is 3.017
# After 3030 steps, per token cost is 2.888
# After 3040 steps, per token cost is 2.955
# After 3050 steps, per token cost is 3.111
# After 3060 steps, per token cost is 2.873
# After 3070 steps, per token cost is 2.906
# After 3080 steps, per token cost is 3.059
# After 3090 steps, per token cost is 2.891
# After 3100 steps, per token cost is 2.952
# After 3110 steps, per token cost is 2.854
# After 3120 steps, per token cost is 2.996
# After 3130 steps, per token cost is 2.833
# After 3140 steps, per token cost is 2.917
# After 3150 steps, per token cost is 2.849
# After 3160 steps, per token cost is 2.979
# After 3170 steps, per token cost is 2.900
# After 3180 steps, per token cost is 2.938
# After 3190 steps, per token cost is 2.847
# After 3200 steps, per token cost is 2.898
# After 3210 steps, per token cost is 2.870
# After 3220 steps, per token cost is 2.787
# After 3230 steps, per token cost is 2.728
# After 3240 steps, per token cost is 2.974
# After 3250 steps, per token cost is 2.902
# After 3260 steps, per token cost is 2.836
# After 3270 steps, per token cost is 2.849
# After 3280 steps, per token cost is 2.867
# After 3290 steps, per token cost is 2.796
# After 3300 steps, per token cost is 2.802
# After 3310 steps, per token cost is 2.896
# After 3320 steps, per token cost is 2.897
# After 3330 steps, per token cost is 2.780
# After 3340 steps, per token cost is 2.692
# After 3350 steps, per token cost is 2.918
# After 3360 steps, per token cost is 2.721
# After 3370 steps, per token cost is 2.861
# After 3380 steps, per token cost is 2.777
# In iteration: 7
# After 3390 steps, per token cost is 2.830
# After 3400 steps, per token cost is 2.768
# After 3410 steps, per token cost is 2.658
# After 3420 steps, per token cost is 2.719
# After 3430 steps, per token cost is 2.677
# After 3440 steps, per token cost is 2.761
# After 3450 steps, per token cost is 2.817
# After 3460 steps, per token cost is 2.781
# After 3470 steps, per token cost is 2.652
# After 3480 steps, per token cost is 2.677
# After 3490 steps, per token cost is 2.688
# After 3500 steps, per token cost is 2.714
# After 3510 steps, per token cost is 2.787
# After 3520 steps, per token cost is 2.783
# After 3530 steps, per token cost is 2.720
# After 3540 steps, per token cost is 2.720
# After 3550 steps, per token cost is 2.651
# After 3560 steps, per token cost is 2.763
# After 3570 steps, per token cost is 2.616
# After 3580 steps, per token cost is 2.678
# After 3590 steps, per token cost is 2.698
# After 3600 steps, per token cost is 2.696
# After 3610 steps, per token cost is 2.699
# After 3620 steps, per token cost is 2.785
# After 3630 steps, per token cost is 2.644
# After 3640 steps, per token cost is 2.678
# After 3650 steps, per token cost is 2.625
# After 3660 steps, per token cost is 2.605
# After 3670 steps, per token cost is 2.616
# After 3680 steps, per token cost is 2.662
# After 3690 steps, per token cost is 2.600
# After 3700 steps, per token cost is 2.694
# After 3710 steps, per token cost is 2.731
# After 3720 steps, per token cost is 2.665
# After 3730 steps, per token cost is 2.591
# After 3740 steps, per token cost is 2.600
# After 3750 steps, per token cost is 2.647
# After 3760 steps, per token cost is 2.583
# After 3770 steps, per token cost is 2.667
# After 3780 steps, per token cost is 2.625
# After 3790 steps, per token cost is 2.562
# After 3800 steps, per token cost is 2.629
# After 3810 steps, per token cost is 2.770
# After 3820 steps, per token cost is 2.579
# After 3830 steps, per token cost is 2.695
# After 3840 steps, per token cost is 2.685
# After 3850 steps, per token cost is 2.574
# After 3860 steps, per token cost is 2.602
# After 3870 steps, per token cost is 2.686
# After 3880 steps, per token cost is 2.557
# After 3890 steps, per token cost is 2.646
# After 3900 steps, per token cost is 2.539
# After 3910 steps, per token cost is 2.650
# After 3920 steps, per token cost is 2.757
# After 3930 steps, per token cost is 2.566
# After 3940 steps, per token cost is 2.658
# After 3950 steps, per token cost is 2.589
# In iteration: 8
# After 3960 steps, per token cost is 2.569
# After 3970 steps, per token cost is 2.475
# After 3980 steps, per token cost is 2.559
# After 3990 steps, per token cost is 2.607
# After 4000 steps, per token cost is 2.536
# After 4010 steps, per token cost is 2.601
# After 4020 steps, per token cost is 2.494
# After 4030 steps, per token cost is 2.469
# After 4040 steps, per token cost is 2.404
# After 4050 steps, per token cost is 2.426
# After 4060 steps, per token cost is 2.394
# After 4070 steps, per token cost is 2.556
# After 4080 steps, per token cost is 2.400
# After 4090 steps, per token cost is 2.406
# After 4100 steps, per token cost is 2.480
# After 4110 steps, per token cost is 2.406
# After 4120 steps, per token cost is 2.543
# After 4130 steps, per token cost is 2.483
# After 4140 steps, per token cost is 2.546
# After 4150 steps, per token cost is 2.338
# After 4160 steps, per token cost is 2.477
# After 4170 steps, per token cost is 2.509
# After 4180 steps, per token cost is 2.432
# After 4190 steps, per token cost is 2.425
# After 4200 steps, per token cost is 2.285
# After 4210 steps, per token cost is 2.358
# After 4220 steps, per token cost is 2.415
# After 4230 steps, per token cost is 2.341
# After 4240 steps, per token cost is 2.355
# After 4250 steps, per token cost is 2.393
# After 4260 steps, per token cost is 2.400
# After 4270 steps, per token cost is 2.379
# After 4280 steps, per token cost is 2.510
# After 4290 steps, per token cost is 2.374
# After 4300 steps, per token cost is 2.410
# After 4310 steps, per token cost is 2.284
# After 4320 steps, per token cost is 2.414
# After 4330 steps, per token cost is 2.336
# After 4340 steps, per token cost is 2.386
# After 4350 steps, per token cost is 2.379
# After 4360 steps, per token cost is 2.361
# After 4370 steps, per token cost is 2.388
# After 4380 steps, per token cost is 2.299
# After 4390 steps, per token cost is 2.350
# After 4400 steps, per token cost is 2.279
# After 4410 steps, per token cost is 2.366
# After 4420 steps, per token cost is 2.353
# After 4430 steps, per token cost is 2.380
# After 4440 steps, per token cost is 2.439
# After 4450 steps, per token cost is 2.395
# After 4460 steps, per token cost is 2.260
# After 4470 steps, per token cost is 2.298
# After 4480 steps, per token cost is 2.409
# After 4490 steps, per token cost is 2.239
# After 4500 steps, per token cost is 2.308
# After 4510 steps, per token cost is 2.357
# In iteration: 9
# After 4520 steps, per token cost is 2.402
# After 4530 steps, per token cost is 2.294
# After 4540 steps, per token cost is 2.257
# After 4550 steps, per token cost is 2.256
# After 4560 steps, per token cost is 2.141
# After 4570 steps, per token cost is 2.158
# After 4580 steps, per token cost is 2.277
# After 4590 steps, per token cost is 2.296
# After 4600 steps, per token cost is 2.209
# After 4610 steps, per token cost is 2.204
# After 4620 steps, per token cost is 2.283
# After 4630 steps, per token cost is 2.158
# After 4640 steps, per token cost is 2.199
# After 4650 steps, per token cost is 2.212
# After 4660 steps, per token cost is 2.187
# After 4670 steps, per token cost is 2.177
# After 4680 steps, per token cost is 2.213
# After 4690 steps, per token cost is 2.164
# After 4700 steps, per token cost is 2.212
# After 4710 steps, per token cost is 2.178
# After 4720 steps, per token cost is 2.225
# After 4730 steps, per token cost is 2.156
# After 4740 steps, per token cost is 2.185
# After 4750 steps, per token cost is 2.172
# After 4760 steps, per token cost is 2.166
# After 4770 steps, per token cost is 2.260
# After 4780 steps, per token cost is 2.153
# After 4790 steps, per token cost is 2.219
# After 4800 steps, per token cost is 2.153
# After 4810 steps, per token cost is 2.140
# After 4820 steps, per token cost is 2.142
# After 4830 steps, per token cost is 2.142
# After 4840 steps, per token cost is 2.217
# After 4850 steps, per token cost is 2.101
# After 4860 steps, per token cost is 2.164
# After 4870 steps, per token cost is 2.089
# After 4880 steps, per token cost is 2.161
# After 4890 steps, per token cost is 2.193
# After 4900 steps, per token cost is 2.170
# After 4910 steps, per token cost is 2.171
# After 4920 steps, per token cost is 2.071
# After 4930 steps, per token cost is 2.140
# After 4940 steps, per token cost is 2.162
# After 4950 steps, per token cost is 2.078
# After 4960 steps, per token cost is 2.144
# After 4970 steps, per token cost is 2.181
# After 4980 steps, per token cost is 2.119
# After 4990 steps, per token cost is 2.054
# After 5000 steps, per token cost is 2.173
# After 5010 steps, per token cost is 2.047
# After 5020 steps, per token cost is 2.114
# After 5030 steps, per token cost is 2.001
# After 5040 steps, per token cost is 2.117
# After 5050 steps, per token cost is 2.106
# After 5060 steps, per token cost is 2.103
# After 5070 steps, per token cost is 2.077
# After 5080 steps, per token cost is 2.164
# In iteration: 10
# After 5090 steps, per token cost is 2.062
# After 5100 steps, per token cost is 2.063
# After 5110 steps, per token cost is 2.003
# After 5120 steps, per token cost is 1.969
# After 5130 steps, per token cost is 1.942
# After 5140 steps, per token cost is 2.000
# After 5150 steps, per token cost is 1.960
# After 5160 steps, per token cost is 1.991
# After 5170 steps, per token cost is 2.025
# After 5180 steps, per token cost is 2.016
# After 5190 steps, per token cost is 1.983
# After 5200 steps, per token cost is 1.905
# After 5210 steps, per token cost is 2.010
# After 5220 steps, per token cost is 1.916
# After 5230 steps, per token cost is 1.969
# After 5240 steps, per token cost is 2.019
# After 5250 steps, per token cost is 1.927
# After 5260 steps, per token cost is 2.007
# After 5270 steps, per token cost is 1.906
# After 5280 steps, per token cost is 1.955
# After 5290 steps, per token cost is 1.900
# After 5300 steps, per token cost is 1.987
# After 5310 steps, per token cost is 1.972
# After 5320 steps, per token cost is 1.939
# After 5330 steps, per token cost is 1.926
# After 5340 steps, per token cost is 1.942
# After 5350 steps, per token cost is 1.880
# After 5360 steps, per token cost is 1.891
# After 5370 steps, per token cost is 1.919
# After 5380 steps, per token cost is 1.862
# After 5390 steps, per token cost is 1.942
# After 5400 steps, per token cost is 1.952
# After 5410 steps, per token cost is 1.920
# After 5420 steps, per token cost is 1.942
# After 5430 steps, per token cost is 1.961
# After 5440 steps, per token cost is 1.856
# After 5450 steps, per token cost is 1.884
# After 5460 steps, per token cost is 1.976
# After 5470 steps, per token cost is 1.822
# After 5480 steps, per token cost is 1.906
# After 5490 steps, per token cost is 1.907
# After 5500 steps, per token cost is 1.891
# After 5510 steps, per token cost is 1.970
# After 5520 steps, per token cost is 1.903
# After 5530 steps, per token cost is 1.900
# After 5540 steps, per token cost is 1.859
# After 5550 steps, per token cost is 1.880
# After 5560 steps, per token cost is 1.905
# After 5570 steps, per token cost is 1.913
# After 5580 steps, per token cost is 1.965
# After 5590 steps, per token cost is 1.870
# After 5600 steps, per token cost is 1.967
# After 5610 steps, per token cost is 1.928
# After 5620 steps, per token cost is 1.940
# After 5630 steps, per token cost is 1.913
# After 5640 steps, per token cost is 1.837
# In iteration: 11
# After 5650 steps, per token cost is 1.939
# After 5660 steps, per token cost is 1.867
# After 5670 steps, per token cost is 1.879
# After 5680 steps, per token cost is 1.776
# After 5690 steps, per token cost is 1.841
# After 5700 steps, per token cost is 1.846
# After 5710 steps, per token cost is 1.791
# After 5720 steps, per token cost is 1.785
# After 5730 steps, per token cost is 1.734
# After 5740 steps, per token cost is 1.853
# After 5750 steps, per token cost is 1.741
# After 5760 steps, per token cost is 1.746
# After 5770 steps, per token cost is 1.759
# After 5780 steps, per token cost is 1.727
# After 5790 steps, per token cost is 1.743
# After 5800 steps, per token cost is 1.727
# After 5810 steps, per token cost is 1.803
# After 5820 steps, per token cost is 1.674
# After 5830 steps, per token cost is 1.734
# After 5840 steps, per token cost is 1.775
# After 5850 steps, per token cost is 1.808
# After 5860 steps, per token cost is 1.689
# After 5870 steps, per token cost is 1.791
# After 5880 steps, per token cost is 1.759
# After 5890 steps, per token cost is 1.718
# After 5900 steps, per token cost is 1.746
# After 5910 steps, per token cost is 1.695
# After 5920 steps, per token cost is 1.776
# After 5930 steps, per token cost is 1.784
# After 5940 steps, per token cost is 1.731
# After 5950 steps, per token cost is 1.727
# After 5960 steps, per token cost is 1.797
# After 5970 steps, per token cost is 1.696
# After 5980 steps, per token cost is 1.670
# After 5990 steps, per token cost is 1.751
# After 6000 steps, per token cost is 1.740
# After 6010 steps, per token cost is 1.714
# After 6020 steps, per token cost is 1.701
# After 6030 steps, per token cost is 1.735
# After 6040 steps, per token cost is 1.704
# After 6050 steps, per token cost is 1.728
# After 6060 steps, per token cost is 1.687
# After 6070 steps, per token cost is 1.662
# After 6080 steps, per token cost is 1.688
# After 6090 steps, per token cost is 1.643
# After 6100 steps, per token cost is 1.658
# After 6110 steps, per token cost is 1.766
# After 6120 steps, per token cost is 1.749
# After 6130 steps, per token cost is 1.656
# After 6140 steps, per token cost is 1.709
# After 6150 steps, per token cost is 1.733
# After 6170 steps, per token cost is 1.760
# After 6180 steps, per token cost is 1.750
# After 6190 steps, per token cost is 1.645
# After 6200 steps, per token cost is 1.648
# After 6210 steps, per token cost is 1.678
# In iteration: 12
# After 6220 steps, per token cost is 1.557
# After 6230 steps, per token cost is 1.602
# After 6240 steps, per token cost is 1.643
# After 6250 steps, per token cost is 1.625
# After 6260 steps, per token cost is 1.595
# After 6270 steps, per token cost is 1.653
# After 6280 steps, per token cost is 1.568
# After 6290 steps, per token cost is 1.465
# After 6300 steps, per token cost is 1.640
# After 6310 steps, per token cost is 1.648
# After 6320 steps, per token cost is 1.576
# After 6330 steps, per token cost is 1.517
# After 6340 steps, per token cost is 1.584
# After 6350 steps, per token cost is 1.541
# After 6360 steps, per token cost is 1.560
# After 6370 steps, per token cost is 1.502
# After 6380 steps, per token cost is 1.571
# After 6390 steps, per token cost is 1.632
# After 6400 steps, per token cost is 1.492
# After 6410 steps, per token cost is 1.539
# After 6420 steps, per token cost is 1.603
# After 6430 steps, per token cost is 1.580
# After 6440 steps, per token cost is 1.573
# After 6450 steps, per token cost is 1.566
# After 6460 steps, per token cost is 1.609
# After 6470 steps, per token cost is 1.495
# After 6480 steps, per token cost is 1.625
# After 6490 steps, per token cost is 1.540
# After 6500 steps, per token cost is 1.571
# After 6510 steps, per token cost is 1.529
# After 6520 steps, per token cost is 1.563
# After 6530 steps, per token cost is 1.601
# After 6540 steps, per token cost is 1.553
# After 6550 steps, per token cost is 1.589
# After 6560 steps, per token cost is 1.562
# After 6570 steps, per token cost is 1.475
# After 6580 steps, per token cost is 1.501
# After 6590 steps, per token cost is 1.555
# After 6600 steps, per token cost is 1.567
# After 6610 steps, per token cost is 1.511
# After 6620 steps, per token cost is 1.499
# After 6630 steps, per token cost is 1.570
# After 6640 steps, per token cost is 1.488
# After 6650 steps, per token cost is 1.508
# After 6660 steps, per token cost is 1.511
# After 6670 steps, per token cost is 1.523
# After 6680 steps, per token cost is 1.520
# After 6690 steps, per token cost is 1.575
# After 6700 steps, per token cost is 1.604
# After 6710 steps, per token cost is 1.554
# After 6720 steps, per token cost is 1.525
# After 6730 steps, per token cost is 1.574
# After 6740 steps, per token cost is 1.629
# After 6750 steps, per token cost is 1.605
# After 6760 steps, per token cost is 1.627
# After 6770 steps, per token cost is 1.576
# In iteration: 13
# After 6780 steps, per token cost is 1.526
# After 6790 steps, per token cost is 1.460
# After 6800 steps, per token cost is 1.500
# After 6810 steps, per token cost is 1.448
# After 6820 steps, per token cost is 1.449
# After 6830 steps, per token cost is 1.413
# After 6840 steps, per token cost is 1.451
# After 6850 steps, per token cost is 1.392
# After 6860 steps, per token cost is 1.423
# After 6870 steps, per token cost is 1.432
# After 6880 steps, per token cost is 1.372
# After 6890 steps, per token cost is 1.453
# After 6900 steps, per token cost is 1.457
# After 6910 steps, per token cost is 1.337
# After 6920 steps, per token cost is 1.461
# After 6930 steps, per token cost is 1.435
# After 6940 steps, per token cost is 1.410
# After 6950 steps, per token cost is 1.400
# After 6960 steps, per token cost is 1.382
# After 6970 steps, per token cost is 1.402
# After 6980 steps, per token cost is 1.363
# After 6990 steps, per token cost is 1.374
# After 7000 steps, per token cost is 1.440
# After 7010 steps, per token cost is 1.417
# After 7020 steps, per token cost is 1.399
# After 7030 steps, per token cost is 1.433
# After 7040 steps, per token cost is 1.450
# After 7050 steps, per token cost is 1.397
# After 7060 steps, per token cost is 1.456
# After 7070 steps, per token cost is 1.537
# After 7080 steps, per token cost is 1.388
# After 7090 steps, per token cost is 1.389
# After 7100 steps, per token cost is 1.423
# After 7110 steps, per token cost is 1.406
# After 7120 steps, per token cost is 1.376
# After 7130 steps, per token cost is 1.376
# After 7140 steps, per token cost is 1.411
# After 7150 steps, per token cost is 1.454
# After 7160 steps, per token cost is 1.399
# After 7170 steps, per token cost is 1.411
# After 7180 steps, per token cost is 1.412
# After 7190 steps, per token cost is 1.364
# After 7200 steps, per token cost is 1.421
# After 7210 steps, per token cost is 1.471
# After 7220 steps, per token cost is 1.441
# After 7230 steps, per token cost is 1.428
# After 7240 steps, per token cost is 1.363
# After 7250 steps, per token cost is 1.445
# After 7260 steps, per token cost is 1.418
# After 7270 steps, per token cost is 1.459
# After 7280 steps, per token cost is 1.334
# After 7290 steps, per token cost is 1.338
# After 7300 steps, per token cost is 1.413
# After 7310 steps, per token cost is 1.529
# After 7320 steps, per token cost is 1.406
# After 7330 steps, per token cost is 1.473
# After 7340 steps, per token cost is 1.365
# In iteration: 14
# After 7350 steps, per token cost is 1.334
# After 7360 steps, per token cost is 1.364
# After 7370 steps, per token cost is 1.344
# After 7380 steps, per token cost is 1.398
# After 7390 steps, per token cost is 1.326
# After 7400 steps, per token cost is 1.360
# After 7410 steps, per token cost is 1.245
# After 7420 steps, per token cost is 1.324
# After 7430 steps, per token cost is 1.271
# After 7440 steps, per token cost is 1.323
# After 7450 steps, per token cost is 1.317
# After 7460 steps, per token cost is 1.246
# After 7470 steps, per token cost is 1.320
# After 7480 steps, per token cost is 1.320
# After 7490 steps, per token cost is 1.299
# After 7500 steps, per token cost is 1.324
# After 7510 steps, per token cost is 1.270
# After 7520 steps, per token cost is 1.209
# After 7530 steps, per token cost is 1.283
# After 7540 steps, per token cost is 1.332
# After 7550 steps, per token cost is 1.302
# After 7560 steps, per token cost is 1.232
# After 7570 steps, per token cost is 1.272
# After 7580 steps, per token cost is 1.252
# After 7590 steps, per token cost is 1.343
# After 7600 steps, per token cost is 1.287
# After 7610 steps, per token cost is 1.313
# After 7620 steps, per token cost is 1.318
# After 7630 steps, per token cost is 1.250
# After 7640 steps, per token cost is 1.248
# After 7650 steps, per token cost is 1.293
# After 7660 steps, per token cost is 1.247
# After 7670 steps, per token cost is 1.280
# After 7680 steps, per token cost is 1.282
# After 7690 steps, per token cost is 1.292
# After 7700 steps, per token cost is 1.235
# After 7710 steps, per token cost is 1.189
# After 7720 steps, per token cost is 1.198
# After 7730 steps, per token cost is 1.279
# After 7740 steps, per token cost is 1.284
# After 7750 steps, per token cost is 1.287
# After 7760 steps, per token cost is 1.284
# After 7770 steps, per token cost is 1.252
# After 7780 steps, per token cost is 1.217
# After 7790 steps, per token cost is 1.309
# After 7800 steps, per token cost is 1.242
# After 7810 steps, per token cost is 1.324
# After 7820 steps, per token cost is 1.234
# After 7830 steps, per token cost is 1.271
# After 7840 steps, per token cost is 1.349
# After 7850 steps, per token cost is 1.309
# After 7860 steps, per token cost is 1.276
# After 7870 steps, per token cost is 1.316
# After 7880 steps, per token cost is 1.285
# After 7890 steps, per token cost is 1.338
# After 7900 steps, per token cost is 1.291
# In iteration: 15
# After 7910 steps, per token cost is 1.330
# After 7920 steps, per token cost is 1.254
# After 7930 steps, per token cost is 1.222
# After 7940 steps, per token cost is 1.222
# After 7950 steps, per token cost is 1.136
# After 7960 steps, per token cost is 1.125
# After 7970 steps, per token cost is 1.236
# After 7980 steps, per token cost is 1.169
# After 7990 steps, per token cost is 1.231
# After 8000 steps, per token cost is 1.168
# After 8010 steps, per token cost is 1.225
# After 8020 steps, per token cost is 1.188
# After 8030 steps, per token cost is 1.202
# After 8040 steps, per token cost is 1.198
# After 8050 steps, per token cost is 1.133
# After 8060 steps, per token cost is 1.164
# After 8070 steps, per token cost is 1.165
# After 8080 steps, per token cost is 1.124
# After 8090 steps, per token cost is 1.245
# After 8100 steps, per token cost is 1.189
# After 8110 steps, per token cost is 1.190
# After 8120 steps, per token cost is 1.140
# After 8130 steps, per token cost is 1.133
# After 8140 steps, per token cost is 1.166
# After 8150 steps, per token cost is 1.147
# After 8160 steps, per token cost is 1.157
# After 8170 steps, per token cost is 1.146
# After 8180 steps, per token cost is 1.222
# After 8190 steps, per token cost is 1.210
# After 8200 steps, per token cost is 1.202
# After 8210 steps, per token cost is 1.235
# After 8220 steps, per token cost is 1.184
# After 8230 steps, per token cost is 1.150
# After 8240 steps, per token cost is 1.168
# After 8250 steps, per token cost is 1.227
# After 8260 steps, per token cost is 1.138
# After 8270 steps, per token cost is 1.163
# After 8280 steps, per token cost is 1.243
# After 8290 steps, per token cost is 1.128
# After 8300 steps, per token cost is 1.133
# After 8310 steps, per token cost is 1.158
# After 8320 steps, per token cost is 1.205
# After 8330 steps, per token cost is 1.158
# After 8340 steps, per token cost is 1.148
# After 8350 steps, per token cost is 1.100
# After 8360 steps, per token cost is 1.175
# After 8370 steps, per token cost is 1.154
# After 8380 steps, per token cost is 1.175
# After 8390 steps, per token cost is 1.188
# After 8400 steps, per token cost is 1.172
# After 8410 steps, per token cost is 1.173
# After 8420 steps, per token cost is 1.161
# After 8430 steps, per token cost is 1.183
# After 8440 steps, per token cost is 1.168
# After 8450 steps, per token cost is 1.225
# After 8460 steps, per token cost is 1.138
# After 8470 steps, per token cost is 1.235
# In iteration: 16
# After 8480 steps, per token cost is 1.109
# After 8490 steps, per token cost is 1.085
# After 8500 steps, per token cost is 1.116
# After 8510 steps, per token cost is 1.045
# After 8520 steps, per token cost is 1.107
# After 8530 steps, per token cost is 1.034
# After 8540 steps, per token cost is 1.149
# After 8550 steps, per token cost is 1.132
# After 8560 steps, per token cost is 1.124
# After 8570 steps, per token cost is 1.088
# After 8580 steps, per token cost is 1.042
# After 8590 steps, per token cost is 1.078
# After 8600 steps, per token cost is 1.038
# After 8610 steps, per token cost is 1.067
# After 8620 steps, per token cost is 1.092
# After 8630 steps, per token cost is 1.076
# After 8640 steps, per token cost is 1.021
# After 8650 steps, per token cost is 1.144
# After 8660 steps, per token cost is 1.068
# After 8670 steps, per token cost is 1.077
# After 8680 steps, per token cost is 1.093
# After 8690 steps, per token cost is 1.098
# After 8700 steps, per token cost is 1.134
# After 8710 steps, per token cost is 1.018
# After 8720 steps, per token cost is 1.106
# After 8730 steps, per token cost is 1.066
# After 8740 steps, per token cost is 1.111
# After 8750 steps, per token cost is 1.069
# After 8760 steps, per token cost is 1.096
# After 8770 steps, per token cost is 1.048
# After 8780 steps, per token cost is 1.090
# After 8790 steps, per token cost is 1.075
# After 8800 steps, per token cost is 1.146
# After 8810 steps, per token cost is 1.102
# After 8820 steps, per token cost is 1.018
# After 8830 steps, per token cost is 1.071
# After 8840 steps, per token cost is 1.066
# After 8850 steps, per token cost is 1.131
# After 8860 steps, per token cost is 1.120
# After 8870 steps, per token cost is 1.062
# After 8880 steps, per token cost is 1.083
# After 8890 steps, per token cost is 1.102
# After 8900 steps, per token cost is 1.113
# After 8910 steps, per token cost is 1.068
# After 8920 steps, per token cost is 1.097
# After 8930 steps, per token cost is 1.074
# After 8940 steps, per token cost is 1.122
# After 8950 steps, per token cost is 1.104
# After 8960 steps, per token cost is 1.144
# After 8970 steps, per token cost is 1.057
# After 8980 steps, per token cost is 1.124
# After 8990 steps, per token cost is 1.115
# After 9000 steps, per token cost is 1.114
# After 9010 steps, per token cost is 1.151
# After 9020 steps, per token cost is 1.137
# After 9030 steps, per token cost is 1.134
# In iteration: 17
# After 9040 steps, per token cost is 1.110
# After 9050 steps, per token cost is 1.056
# After 9060 steps, per token cost is 1.063
# After 9070 steps, per token cost is 1.010
# After 9080 steps, per token cost is 1.018
# After 9090 steps, per token cost is 0.982
# After 9100 steps, per token cost is 0.977
# After 9110 steps, per token cost is 0.995
# After 9120 steps, per token cost is 1.084
# After 9130 steps, per token cost is 0.979
# After 9140 steps, per token cost is 1.002
# After 9150 steps, per token cost is 1.001
# After 9160 steps, per token cost is 1.049
# After 9170 steps, per token cost is 0.997
# After 9180 steps, per token cost is 1.016
# After 9190 steps, per token cost is 0.999
# After 9200 steps, per token cost is 0.987
# After 9210 steps, per token cost is 0.988
# After 9220 steps, per token cost is 0.984
# After 9230 steps, per token cost is 1.029
# After 9240 steps, per token cost is 0.982
# After 9250 steps, per token cost is 1.037
# After 9260 steps, per token cost is 0.984
# After 9270 steps, per token cost is 1.006
# After 9280 steps, per token cost is 0.993
# After 9290 steps, per token cost is 0.994
# After 9300 steps, per token cost is 1.018
# After 9310 steps, per token cost is 1.014
# After 9320 steps, per token cost is 0.914
# After 9330 steps, per token cost is 0.995
# After 9340 steps, per token cost is 0.958
# After 9350 steps, per token cost is 0.970
# After 9360 steps, per token cost is 0.978
# After 9370 steps, per token cost is 1.001
# After 9380 steps, per token cost is 0.992
# After 9390 steps, per token cost is 1.009
# After 9400 steps, per token cost is 1.052
# After 9410 steps, per token cost is 1.036
# After 9420 steps, per token cost is 1.043
# After 9430 steps, per token cost is 0.968
# After 9440 steps, per token cost is 0.981
# After 9450 steps, per token cost is 0.991
# After 9460 steps, per token cost is 1.017
# After 9470 steps, per token cost is 0.999
# After 9480 steps, per token cost is 1.006
# After 9490 steps, per token cost is 1.081
# After 9500 steps, per token cost is 1.027
# After 9510 steps, per token cost is 1.004
# After 9520 steps, per token cost is 1.001
# After 9530 steps, per token cost is 1.040
# After 9540 steps, per token cost is 1.003
# After 9550 steps, per token cost is 0.996
# After 9560 steps, per token cost is 0.951
# After 9570 steps, per token cost is 1.039
# After 9580 steps, per token cost is 1.015
# After 9590 steps, per token cost is 1.050
# After 9600 steps, per token cost is 0.976
# In iteration: 18
# After 9610 steps, per token cost is 0.974
# After 9620 steps, per token cost is 0.993
# After 9630 steps, per token cost is 0.915
# After 9640 steps, per token cost is 0.880
# After 9650 steps, per token cost is 0.950
# After 9660 steps, per token cost is 0.891
# After 9670 steps, per token cost is 0.928
# After 9680 steps, per token cost is 0.941
# After 9690 steps, per token cost is 0.926
# After 9700 steps, per token cost is 0.880
# After 9710 steps, per token cost is 0.894
# After 9720 steps, per token cost is 0.978
# After 9730 steps, per token cost is 0.893
# After 9740 steps, per token cost is 0.954
# After 9750 steps, per token cost is 0.962
# After 9760 steps, per token cost is 0.881
# After 9770 steps, per token cost is 0.914
# After 9780 steps, per token cost is 1.000
# After 9790 steps, per token cost is 0.943
# After 9800 steps, per token cost is 0.934
# After 9810 steps, per token cost is 0.869
# After 9820 steps, per token cost is 0.911
# After 9830 steps, per token cost is 0.965
# After 9840 steps, per token cost is 0.965
# After 9850 steps, per token cost is 0.954
# After 9860 steps, per token cost is 0.927
# After 9870 steps, per token cost is 0.895
# After 9880 steps, per token cost is 0.968
# After 9890 steps, per token cost is 0.902
# After 9900 steps, per token cost is 0.909
# After 9910 steps, per token cost is 0.881
# After 9920 steps, per token cost is 0.870
# After 9930 steps, per token cost is 0.924
# After 9940 steps, per token cost is 0.922
# After 9950 steps, per token cost is 0.932
# After 9960 steps, per token cost is 0.953
# After 9970 steps, per token cost is 0.993
# After 9980 steps, per token cost is 0.852
# After 9990 steps, per token cost is 0.956
# After 10000 steps, per token cost is 0.932
# After 10010 steps, per token cost is 0.848
# After 10020 steps, per token cost is 0.958
# After 10030 steps, per token cost is 0.879
# After 10040 steps, per token cost is 0.938
# After 10050 steps, per token cost is 0.911
# After 10060 steps, per token cost is 0.910
# After 10070 steps, per token cost is 0.982
# After 10080 steps, per token cost is 0.927
# After 10090 steps, per token cost is 0.890
# After 10100 steps, per token cost is 0.969
# After 10110 steps, per token cost is 0.984
# After 10120 steps, per token cost is 1.029
# After 10130 steps, per token cost is 0.958
# After 10140 steps, per token cost is 0.919
# After 10150 steps, per token cost is 0.936
# After 10160 steps, per token cost is 0.969
# In iteration: 19
# After 10170 steps, per token cost is 0.935
# After 10180 steps, per token cost is 0.853
# After 10190 steps, per token cost is 0.847
# After 10200 steps, per token cost is 0.846
# After 10210 steps, per token cost is 0.859
# After 10220 steps, per token cost is 0.920
# After 10230 steps, per token cost is 0.883
# After 10240 steps, per token cost is 0.879
# After 10250 steps, per token cost is 0.827
# After 10260 steps, per token cost is 0.874
# After 10270 steps, per token cost is 0.946
# After 10280 steps, per token cost is 0.828
# After 10290 steps, per token cost is 0.936
# After 10300 steps, per token cost is 0.873
# After 10310 steps, per token cost is 0.822
# After 10320 steps, per token cost is 0.822
# After 10330 steps, per token cost is 0.815
# After 10340 steps, per token cost is 0.866
# After 10350 steps, per token cost is 0.872
# After 10360 steps, per token cost is 0.811
# After 10370 steps, per token cost is 0.930
# After 10380 steps, per token cost is 0.910
# After 10390 steps, per token cost is 0.864
# After 10400 steps, per token cost is 0.860
# After 10410 steps, per token cost is 0.821
# After 10420 steps, per token cost is 0.877
# After 10430 steps, per token cost is 0.903
# After 10440 steps, per token cost is 0.860
# After 10450 steps, per token cost is 0.891
# After 10460 steps, per token cost is 0.838
# After 10470 steps, per token cost is 0.831
# After 10480 steps, per token cost is 0.849
# After 10490 steps, per token cost is 0.928
# After 10500 steps, per token cost is 0.868
# After 10510 steps, per token cost is 0.889
# After 10520 steps, per token cost is 0.857
# After 10530 steps, per token cost is 0.890
# After 10540 steps, per token cost is 0.841
# After 10550 steps, per token cost is 0.828
# After 10560 steps, per token cost is 0.859
# After 10570 steps, per token cost is 0.856
# After 10580 steps, per token cost is 0.848
# After 10590 steps, per token cost is 0.853
# After 10600 steps, per token cost is 0.815
# After 10610 steps, per token cost is 0.849
# After 10620 steps, per token cost is 0.855
# After 10630 steps, per token cost is 0.799
# After 10640 steps, per token cost is 0.875
# After 10650 steps, per token cost is 0.857
# After 10660 steps, per token cost is 0.895
# After 10670 steps, per token cost is 0.895
# After 10680 steps, per token cost is 0.860
# After 10690 steps, per token cost is 0.861
# After 10700 steps, per token cost is 0.908
# After 10710 steps, per token cost is 0.886
# After 10720 steps, per token cost is 0.909
# After 10730 steps, per token cost is 0.958
# In iteration: 20
# After 10740 steps, per token cost is 0.822
# After 10750 steps, per token cost is 0.805
# After 10760 steps, per token cost is 0.786
# After 10770 steps, per token cost is 0.810
# After 10780 steps, per token cost is 0.803
# After 10790 steps, per token cost is 0.797
# After 10800 steps, per token cost is 0.798
# After 10810 steps, per token cost is 0.805
# After 10820 steps, per token cost is 0.787
# After 10830 steps, per token cost is 0.791
# After 10840 steps, per token cost is 0.792
# After 10850 steps, per token cost is 0.772
# After 10860 steps, per token cost is 0.812
# After 10870 steps, per token cost is 0.796
# After 10880 steps, per token cost is 0.775
# After 10890 steps, per token cost is 0.765
# After 10900 steps, per token cost is 0.785
# After 10910 steps, per token cost is 0.803
# After 10920 steps, per token cost is 0.852
# After 10930 steps, per token cost is 0.800
# After 10940 steps, per token cost is 0.815
# After 10950 steps, per token cost is 0.856
# After 10960 steps, per token cost is 0.826
# After 10970 steps, per token cost is 0.804
# After 10980 steps, per token cost is 0.804
# After 10990 steps, per token cost is 0.770
# After 11000 steps, per token cost is 0.848
# After 11010 steps, per token cost is 0.779
# After 11020 steps, per token cost is 0.856
# After 11030 steps, per token cost is 0.807
# After 11040 steps, per token cost is 0.808
# After 11050 steps, per token cost is 0.789
# After 11060 steps, per token cost is 0.775
# After 11070 steps, per token cost is 0.823
# After 11080 steps, per token cost is 0.829
# After 11090 steps, per token cost is 0.787
# After 11100 steps, per token cost is 0.824
# After 11110 steps, per token cost is 0.814
# After 11120 steps, per token cost is 0.835
# After 11130 steps, per token cost is 0.819
# After 11140 steps, per token cost is 0.779
# After 11150 steps, per token cost is 0.791
# After 11160 steps, per token cost is 0.826
# After 11170 steps, per token cost is 0.790
# After 11180 steps, per token cost is 0.767
# After 11190 steps, per token cost is 0.842
# After 11200 steps, per token cost is 0.829
# After 11210 steps, per token cost is 0.846
# After 11220 steps, per token cost is 0.847
# After 11230 steps, per token cost is 0.826
# After 11240 steps, per token cost is 0.874
# After 11250 steps, per token cost is 0.808
# After 11260 steps, per token cost is 0.762
# After 11270 steps, per token cost is 0.923
# After 11280 steps, per token cost is 0.820
# After 11290 steps, per token cost is 0.853
